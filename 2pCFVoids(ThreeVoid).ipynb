# %%
#libraries needed

import numpy as np
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

RADIUS_A = 50
BOX_SIZE = 1000
HEIGTH = 1000
WIDTH = 1000


def GenerateRandomPoints(numberPoints,radius,centroids):
    "Function to generate samples points"
    d = dict(); 
    arrayOfPoints = []
    xCoordinates = []
    yCoordinates = []
    for i in range(numberPoints):
        angle = 2 * np.pi * np.random.random_sample()
        x = radius * np.random.random() * np.cos(angle)
        y =  radius * np.random.random() * np.sin(angle)
        coordinates = [x + centroids[0], y + centroids[1] ]
        xCoordinates.append(x + centroids[0])
        yCoordinates.append(y+ centroids[0])
        arrayOfPoints.append(coordinates)

        d['arrayOfPoints'] = arrayOfPoints
        d['x'] = xCoordinates
        d['y'] = yCoordinates
    
    return d


def GenerateRandomPointsInBox(numberPoints, heigth, width):
    "Functiom to generate samples box"
    d = dict(); 
    xCoordinates = []
    yCoordinates = []
    for i in range(numberPoints):
        x = np.random.randint(0, width) 
        y = np.random.randint(0, heigth)
        xCoordinates.append(x)
        yCoordinates.append(y)

        d['x'] = xCoordinates
        d['y'] = yCoordinates
    
    return d

#Box
box = GenerateRandomPointsInBox(5000, HEIGTH, WIDTH)

#Voids 1
centroids = [300,300]
c1 = GenerateRandomPoints(200, RADIUS_A, centroids)

#Voids 2
centroids2 = [650,850]
c2 = GenerateRandomPoints(200, RADIUS_A, centroids2)

#Voids 3
centroids2 = [200,800]
c3 = GenerateRandomPoints(200, RADIUS_A, centroids2)

plt.plot(box['x'], box['y'], linestyle='', marker='o', markersize=0.2) 
plt.plot(c1['x'], c1['y'], marker='o', markersize=0.1)
plt.plot(c2['x'], c2['y'], marker='o', markersize=0.1)
plt.plot(c3['x'], c2['y'], marker='o', markersize=0.1)

#plt.figure(figsize=(50,50))
plt.show()

# %%
#We calculate the distance between distances

distanceVoids1=[]
for i in range (len(c1['x'])):
      for j in range(i+1,len(c1['x'])):
        distanceVoids1_ij=np.sqrt((c1['x'][i]-c1['x'][j])**2+(c1['y'][i]-c1['y'][j])**2)
        distanceVoids1.append(distanceVoids1_ij)
        
distanceVoids2=[]
for i in range (len(c2['x'])):
      for j in range(i+1,len(c2['x'])):
        distanceVoids2_ij=np.sqrt((c2['x'][i]-c2['x'][j])**2+(c2['y'][i]-c2['y'][j])**2)
        distanceVoids2.append(distanceVoids2_ij)

distanceVoids3=[]
for i in range (len(c3['x'])):
      for j in range(i+1,len(c3['x'])):
        distanceVoids3_ij=np.sqrt((c3['x'][i]-c3['x'][j])**2+(c3['y'][i]-c3['y'][j])**2)
        distanceVoids3.append(distanceVoids3_ij)
        
# We create the histogram for Voids1, Voids2 and Voids3
DD1h = plt.hist(distanceVoids1, bins=200,  facecolor='blue', label=r'Distances void 1', linewidth=0, alpha=0.5)[0]
DD2h = plt.hist(distanceVoids2, bins=200,  facecolor='red', label=r'Distances Void2', linewidth=0, alpha=0.5)[0]
DD3h = plt.hist(distanceVoids3, bins=200,  facecolor='black', label=r'Distances Void2', linewidth=0, alpha=0.5)[0]
plt.xlabel('Distance')
plt.ylabel('Number of points')
plt.legend(loc=1)
plt.title('Distances of points in voids 1')
plt.show()
print len(distanceVoids1)
print len(distanceVoids2)
print len(distanceVoids3)
# Out:
# 19900
# 19900
# 19900

# %%
#We calculate the distances between random points

d_box=[]
for i in range (len(box['x'])):
      for j in range(i+1,len(box['x'])):
        d_box_ij=np.sqrt((box['x'][i]-box['x'][j])**2+(box['y'][i]-box['y'][j])**2)
        d_box.append(d_box_ij)
        
# We create the histogram for random-data1.
RRh = plt.hist(d_box, bins=200,  facecolor='blue', label=r'Distances in box', linewidth=0, alpha=0.5)[0]
plt.xlabel('Distance')
plt.ylabel('Number of points')
plt.legend(loc=1)
plt.title('Distances of points in box')
plt.show()
print len(box['x'])
print len(d_box)
# Out:
# 5000
# 12497500

# %%
#We calculate the distance between void points and random points in box.

distancesVoid1Box=[]
for i in range (len(c1['x'])):
      for j in range(i+1,len(c1['x'])):
        distancesVoid1Box_ij=np.sqrt((c1['x'][i]-box['x'][j])**2+(c1['y'][i]-box['y'][j])**2)
        distancesVoid1Box.append(distancesVoid1Box_ij)
        
distancesVoid2Box=[]
for i in range (len(c2['x'])):
      for j in range(i+1,len(c2['x'])):
        distancesVoid2Box_ij=np.sqrt((c2['x'][i]-box['x'][j])**2+(c2['y'][i]-box['y'][j])**2)
        distancesVoid2Box.append(distancesVoid2Box_ij)
        
distancesVoid3Box=[]
for i in range (len(c3['x'])):
      for j in range(i+1,len(c3['x'])):
        distancesVoid3Box_ij=np.sqrt((c3['x'][i]-box['x'][j])**2+(c3['y'][i]-box['y'][j])**2)
        distancesVoid3Box.append(distancesVoid3Box_ij)
        
# We create the histogram for random-data1.
D1Rh = plt.hist(distancesVoid1Box, bins=200,  facecolor='blue', label=r'Distances in D1R', linewidth=0, alpha=0.9)[0]
D2Rh = plt.hist(distancesVoid2Box, bins=200,  facecolor='red', label=r'Distances in box', linewidth=0, alpha=0.9)[0]
D3Rh = plt.hist(distancesVoid3Box, bins=200,  facecolor='black', label=r'Distances in box', linewidth=0, alpha=0.9)[0]
plt.xlabel('Distance')
plt.ylabel('Number of points')
plt.legend(loc=1)
plt.title('Distances of points in D1R')
plt.show()
print len(distancesVoid1Box)
# Out:
# 19900

# %%
# Davis-Peebles:
DP1 = (DD1h/RRh)-1
DP2 = (DD2h/RRh)-1
DP3 = (DD3h/RRh)-1

D1R = np.array(distancesVoid1Box)
D2R = np.array(distancesVoid2Box)

# Landy-Szalay:
LS1 = (DD1h - 2*D1Rh + RRh)/RRh
LS2 = (DD2h - 2*D2Rh + RRh)/RRh
LS3 = (DD3h - 2*D3Rh + RRh)/RRh
# Out:
# C:\Users\DANTE\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in divide
#
# C:\Users\DANTE\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\DANTE\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in divide
#   after removing the cwd from sys.path.
# C:\Users\DANTE\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in divide
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\DANTE\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in divide
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
max_dist = 100*np.sqrt(2)

plt.plot(DP1,color='r',label=r'$Void\_1$')
plt.plot(DP2,color='b',label=r'$Void\_2$')
plt.plot(DP3,color='b',label=r'$Void\_2$')
plt.axhline(y=0,linestyle='--',linewidth=1,color='k')
plt.title('Davis-Peebles Estimator')
plt.xlabel(r'$r$')
plt.ylabel(r'$\epsilon(r)$')
plt.xlim(0,80)
plt.ylim(-1.25,-0.6)
plt.legend()
plt.show()

plt.plot(LS1,color='r',label=r'$Void\_1$')
plt.plot(LS2,color='b',label=r'$Void\_2$')
plt.plot(LS3,color='b',label=r'$Void\_2$')
plt.axhline(y=0,linestyle='--',linewidth=1,color='k')
plt.title('Landy-Szalay Estimator')
plt.xlabel(r'$r$')
plt.ylabel(r'$\epsilon(r)$')
plt.xlim(0,80)
plt.ylim(-0.2,1.2)
plt.legend()
plt.show()
